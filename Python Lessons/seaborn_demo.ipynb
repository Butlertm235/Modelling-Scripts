# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bokeh.plotting import figure, output_file, show
# %matplotlib inline

# %%
database = pd.read_csv('ATC_1.csv', index_col=0, encoding='latin').drop(columns=["Name"])
database
# Out:
#     Road Name Type 2  Total  HGV  Car  LGV  Cycle  OGV1  OGV2  Stage  Daily?
# #
# 1         A10    M22    318   45   49   49     65    65    45      1   False
# 2         A10    M22    405   60   62   63     80    80    60      2   False
# 3         A10    M22    525   80   82   83    100   100    80      3   False
# 4          M1    NaN    309   39   52   43     60    50    65      1   False
# 5          M1    NaN    405   58   64   58     80    65    80      2   False
# ..        ...    ...    ...  ...  ...  ...    ...   ...   ...    ...     ...
# 147       A15    NaN    300   41   64   45     50    50    50      1   False
# 148       A15    NaN    420   61   84   65     70    70    70      2   False
# 149       A15     M5    600   91  134   95    100   100    80      3   False
# 150       A30    NaN    680  106  110   90    154    90   130      1    True
# 151       A30    NaN    600  100  100  100    100   100   100      1   False
#
# [151 rows x 11 columns]

# %%
sns.set_style('whitegrid')

# %%
car = database["Car"]
lgv = database["LGV"]
plt.scatter(car,lgv)
plt.xlabel("Car")
plt.ylabel("LGV")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lmplot(x='Car', y='LGV', data=database)

# %%
sns.lmplot(x='Car', y='LGV', data=database, fit_reg=False, hue='Stage')

# %%
sns.lmplot(x='Car', y='LGV', data=database, fit_reg=False, hue='Stage')
plt.ylim(0,200)
plt.xlim(0,160)
# Out:
# (0.0, 160.0)

# %%
sns.boxplot(data=database)
# Out:
# <AxesSubplot: >

# %%
stats_database = database.drop(columns=["Total", "Stage", "Daily?"])
sns.boxplot(data=stats_database)
# Out:
# <AxesSubplot: >

# %%
sns.set_style('darkgrid')
sns.boxplot(data=stats_database)
# Out:
# <AxesSubplot: >

# %%
road_key_colors = ['#78C850',  
                    '#F08030',  
                    '#6890F0',  
                    '#A8B820',  
                    '#A8A878',  
                    '#A040A0',  
                    '#F8D030',  
                    '#E0C068',  
                    '#EE99AC',  
                    '#C03028',  
                    '#F85888',  
                    '#B8A038',  
                    '#705898',  
                    '#98D8D8',  
                    '#7038F8',  
                   ]

# %%
plt.figure(figsize=(11,6)) # Set plot dimensions
sns.swarmplot(x='Road Name', y='Car', data=database, 
              palette=road_key_colors)
# Out:
# C:\Users\UKTMB001\AppData\Local\Temp\ipykernel_19936\1797763025.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='Road Name', y='Car', data=database,
# <AxesSubplot: xlabel='Road Name', ylabel='Car'>

# %%
plt.figure(figsize=(11,6))
plt.ylim(-20,160) 
# Create plot
sns.violinplot(x='Road Name',
               y='Car', 
               data=database, 
               inner=None, # Remove the bars inside the violins
               palette=road_key_colors)

sns.swarmplot(x='Road Name',
               y='Car',  
              data=database, 
              color='k', # Make points black
              alpha=0.7) # and slightly transparent
 
# Set title with matplotlib
plt.title('Car Count by Road')
# Out:
# Text(0.5, 1.0, 'Car Count by Road')
